# %%
from datadownloader.Economy import Currency

import matplotlib.pyplot as plt

# %% [markdown]
# # Get exchange rate between currencies (Default base is USD)

# %%
usd_cad = Currency('CAD')
print(usd_cad.exchange_symbol)
usd_cad_hist = usd_cad.get_history()
print(usd_cad_hist)
plt.plot(usd_cad_hist)
plt.show()
# Out:
# USD/CAD: USD to CAD
#              Value
# Date
# 1971-01-04  1.0109
# 1971-01-05  1.0102
# 1971-01-06  1.0106
# 1971-01-07  1.0148
# 1971-01-08  1.0154
# ...            ...
# 2020-06-15  1.3618
# 2020-06-16  1.3562
# 2020-06-17  1.3570
# 2020-06-18  1.3593
# 2020-06-19  1.3601
#
# [12417 rows x 1 columns]

# %%
jpy_cad = Currency('CAD', base='JPY')
print(jpy_cad.exchange_symbol)
jpy_cad_hist = jpy_cad.get_history()
print(jpy_cad_hist)
plt.plot(jpy_cad_hist)
plt.show()
# Out:
# JPY/CAD: JPY to CAD
#                Value
# Date
# 1971-01-04  0.002826
# 1971-01-05  0.002823
# 1971-01-06  0.002824
# 1971-01-07  0.002836
# 1971-01-08  0.002838
# ...              ...
# 2020-06-15  0.012688
# 2020-06-16  0.012633
# 2020-06-17  0.012652
# 2020-06-18  0.012730
# 2020-06-19  0.012724
#
# [12417 rows x 1 columns]

# %% [markdown]
# # Get Economy indicators:
#
# For indicator code, refer to FRED's api on Quandl: https://www.quandl.com/data/FRED-Federal-Reserve-Economic-Data/documentation?anchor=data-organization

# %%
from datadownloader.Economy import EconomyIndicator

us_gdp = EconomyIndicator('GDP')
us_gdp.get_history()
# Out:
#                 Value
# Date
# 1947-01-01    243.164
# 1947-04-01    245.968
# 1947-07-01    249.585
# 1947-10-01    259.745
# 1948-01-01    265.742
# ...               ...
# 2019-01-01  21098.827
# 2019-04-01  21340.267
# 2019-07-01  21542.540
# 2019-10-01  21729.124
# 2020-01-01  21539.689
#
# [293 rows x 1 columns]

# %%
us_unemployment_rate = EconomyIndicator('UNRATE')
us_unemployment_rate.get_history()
# Out:
#             Value
# Date
# 1948-01-01    3.4
# 1948-02-01    3.8
# 1948-03-01    4.0
# 1948-04-01    3.9
# 1948-05-01    3.5
# ...           ...
# 2020-01-01    3.6
# 2020-02-01    3.5
# 2020-03-01    4.4
# 2020-04-01   14.7
# 2020-05-01   13.3
#
# [869 rows x 1 columns]

# %%
us_debt_gdp_ratio = EconomyIndicator('GFDEGDQ188S')
us_debt_gdp_ratio.get_history()
# Out:
#                 Value
# Date
# 1966-01-01   40.33999
# 1966-04-01   39.26763
# 1966-07-01   39.62091
# 1966-10-01   39.51977
# 1967-01-01   39.20383
# ...               ...
# 2019-01-01  104.40334
# 2019-04-01  103.20060
# 2019-07-01  105.46297
# 2019-10-01  106.77550
# 2020-01-01  107.81870
#
# [217 rows x 1 columns]

# %% [markdown]
# # Get Treasury Yield across many timeframes:

# %%
from datadownloader.Economy import TreasuryYield

us_ty = TreasuryYield()
us_ty.get_history()
# Out:
#             1 MO  2 MO  3 MO  6 MO  1 YR  2 YR  3 YR  5 YR  7 YR  10 YR  \
# Date
# 1990-01-02   NaN   NaN  7.83  7.89  7.81  7.87  7.90  7.87  7.98   7.94
# 1990-01-03   NaN   NaN  7.89  7.94  7.85  7.94  7.96  7.92  8.04   7.99
# 1990-01-04   NaN   NaN  7.84  7.90  7.82  7.92  7.93  7.91  8.02   7.98
# 1990-01-05   NaN   NaN  7.79  7.85  7.79  7.90  7.94  7.92  8.03   7.99
# 1990-01-08   NaN   NaN  7.79  7.88  7.81  7.90  7.95  7.92  8.05   8.02
# ...          ...   ...   ...   ...   ...   ...   ...   ...   ...    ...
# 2020-06-19  0.13  0.14  0.15  0.17  0.18  0.19  0.22  0.33  0.53   0.70
# 2020-06-22  0.14  0.15  0.16  0.18  0.17  0.19  0.22  0.34  0.54   0.71
# 2020-06-23  0.12  0.14  0.16  0.17  0.18  0.18  0.22  0.33  0.54   0.72
# 2020-06-24  0.11  0.14  0.15  0.17  0.17  0.19  0.21  0.33  0.52   0.69
# 2020-06-25  0.13  0.14  0.16  0.17  0.17  0.17  0.21  0.32  0.53   0.68
#
#             20 YR  30 YR
# Date
# 1990-01-02    NaN   8.00
# 1990-01-03    NaN   8.04
# 1990-01-04    NaN   8.04
# 1990-01-05    NaN   8.06
# 1990-01-08    NaN   8.09
# ...           ...    ...
# 2020-06-19   1.23   1.47
# 2020-06-22   1.23   1.46
# 2020-06-23   1.25   1.49
# 2020-06-24   1.21   1.44
# 2020-06-25   1.20   1.43
#
# [7627 rows x 12 columns]
